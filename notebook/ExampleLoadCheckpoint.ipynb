# %% [markdown]
# # Load and Prompt a Checkpoint
#
# This notebook demonstrates how to reconstruct a model from a file checkpoint.
# To load the vocabulary and tokenizer used to train this model correctly, this notebook assumes that the corresponding maze datasets are loaded into MongoDB correctly, as outlined in [TokenDatasets.ipynb](TokenDatasets.ipynb).
#
# A single checkpoint holds data about
# * Hyper-parameters used for training (excluding the token vocabulary, which is stored together with the corresponding token dataset).
# * All model parameters
# * Optimizer state
# * Number of gradient steps at which the model was solved
#
# This notebook only outlines how a model can be reconstructed from a checkpoint file.
# To use any of the other workflows included in this code base, the checkpoint files must be be first imported into MongoDB.
# In this notebook we focus on the checkpoint resulting from the run `maze-sweep-rep-nondet-small-0` and assume that the file `maze-sweep-rep-nondet-small-0.ckpt` is present at the project's root directory.
# This checkpoint file can be downloaded [here](https://dl.fbaipublicfiles.com/searchformer/ckptDB/maze-sweep-rep-nondet-small-0.ckpt).
# The file [`checkpoint_index.csv`](../doc.checkpoint_index.csv) lists all released checkpoints and their corresponding download link.

# %% [markdown]
# First different modules are imported.

# %%
import sys 
sys.path.append("..")

import logging
import torch
from searchformer.train import Checkpoint
from searchformer.transformer import EncoderDecoderConfig, sample_probability
from searchformer.trace import DictTokenizer, TokenizedDataset


logging.basicConfig(
    level=logging.DEBUG,
    format="%(levelname)s - %(asctime)s - %(name)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)

# %% [markdown]
# Loading the checkpoint file `../maze-sweep-rep-nondet-small-0.ckpt` and printing the training configuration.

# %%
ckpt = Checkpoint.from_file("/home/rahim/sokoban-7722-m-trace-plan-100k-2-step-3.ckpt")
ckpt.config
# Out:
# {'_id': 'sokoban-7722-m-trace-plan-100k-2-step-3',
#  'data': {'train_name': '65ca57d67f455f390d05bf33.improved',
#   'test_name': 'sokoban.7-by-7-walls-2-boxes-2.with-box-40k',
#   'batch_size': 1,
#   'plan_only': False,
#   'num_train_sequences': 100000,
#   'num_test_sequences': 1000,
#   'load_batch_size': 10000,
#   'num_workers': 2,
#   'min_reasoning_len': 0,
#   'max_reasoning_len': 10000},
#  'encoder': 'enc-m-s',
#  'decoder': 'dec-m-s',
#  'optimizer': {'lr': 7.5e-05,
#   'lr_schedule': 'cosine',
#   'train_steps': 10000,
#   'warmup': 2000,
#   'beta_0': 0.9,
#   'beta_1': 0.99,
#   'cycle_length': 1.0,
#   'cosine_theta': 1.0,
#   'lr_min_ratio': 0.1},
#  'log_interval': 200,
#  'eval_interval': 5000,
#  'start_checkpoint': 'sokoban-7722-m-trace-plan-100k-2-step-2'}

# %% [markdown]
# First loading the tokenized dataset and constructing a `DictTokenizer` object.
# This object is used to map word token sequences to integer lists.
# Subsequently, an `EncoderDecoderConfig` object is constructed which holds all network architecture model parameters.
# From this object the actual encoder-decoder Transformer is constructed and the model parameters (state dictionary) are loaded in.
# The example below runs inference on CPU for the smallest model and shortest sequences to reduce compute requirements.

# %%
ckpt.checkpoint_id
# Out:
# 'sokoban-7722-m-trace-plan-100k-2-step-3'

# %%
# Load vocabulary from tokenized dataset. This is needed to load the training token vocabulary and a test prompt.
tok_dataset = TokenizedDataset(ckpt.config_obj.data.train_name)
# Out:
# INFO - 2025-05-06 06:07:13 - root - Connecting to mongodb://localhost:27017/mongo
# DEBUG - 2025-05-06 06:07:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Starting topology monitoring"}
# DEBUG - 2025-05-06 06:07:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "previousDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Unknown, servers: []>", "newDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None>]>", "message": "Topology description changed"}
# DEBUG - 2025-05-06 06:07:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "serverHost": "localhost", "serverPort": 27017, "message": "Starting server monitoring"}
# DEBUG - 2025-05-06 06:07:13 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection pool created", "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:07:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.0107979996973881, "reply": "{\"helloOk\": true, \"ismaster\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:07:13.396Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:07:13 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection pool ready", "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "previousDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None>]>", "newDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Standalone, rtt: 0.0010107979996973881>]>", "message": "Topology description changed"}
# DEBUG - 2025-05-06 06:07:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:07:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10006.402913999409, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:07:23.410Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:07:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:07:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 9999.242914998831, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:07:33.410Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:07:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:07:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10003.3466449986, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:07:43.415Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:07:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:07:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.970829001555, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:07:53.425Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:07:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:08:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.115500999542, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:08:03.436Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:08:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:08:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.047045999978, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:08:13.447Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:08:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:08:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10004.863643000135, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:08:23.453Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:08:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:08:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10007.39658600105, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:08:33.463Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:08:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:08:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10013.163008999982, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:08:43.477Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:08:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:08:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.199871999954, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:08:53.488Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:08:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:09:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.085495999898, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:09:03.499Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:09:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:09:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.539906999635, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:09:13.510Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:09:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:09:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.198751000236, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:09:23.520Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:09:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:09:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.154723999018, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:09:33.530Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:09:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:09:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10007.947605001391, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:09:43.540Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:09:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:09:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10007.784625000568, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:09:53.549Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:09:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:10:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.980122000139, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:10:03.559Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:10:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:10:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.326784000019, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:10:13.569Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:10:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:10:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.562310000343, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:10:23.579Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:10:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:10:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10007.60177400116, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:10:33.588Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:10:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:10:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.52014899849, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:10:43.599Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:10:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:10:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10011.135524000565, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:10:53.611Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:10:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:11:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10006.919467999978, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:11:03.620Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:11:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:11:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.371072999784, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:11:13.631Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:11:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:11:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10010.174099999858, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:11:23.642Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:11:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:11:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10006.77685699884, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:11:33.651Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:11:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:11:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.036842999194, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:11:43.661Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:11:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:11:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.545926000807, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:11:53.671Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:11:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:12:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10007.551036000223, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:12:03.681Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:12:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:12:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.02514200061, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:12:13.691Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:12:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:12:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.17969800139, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:12:23.702Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:12:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:12:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.766821000085, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:12:33.713Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:12:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:12:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10012.59701699928, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:12:43.727Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:12:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:12:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.013430000574, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:12:53.736Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:12:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:13:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10005.481797001266, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:13:03.743Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:13:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:13:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.816513998681, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:13:13.753Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:13:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:13:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.018802000355, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:13:23.763Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:13:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:13:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 9999.778308001623, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:13:33.765Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:13:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:13:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10001.841556999352, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:13:43.768Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:13:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:13:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.574165000231, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:13:53.779Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:13:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:14:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10012.25290200091, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:14:03.793Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:14:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:14:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.562331999201, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:14:13.803Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:14:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:14:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.974583999792, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:14:23.814Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:14:23 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:14:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10012.38151600046, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:14:33.828Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:14:33 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:14:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.27853300143, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:14:43.838Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:14:43 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:14:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.261125998615, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:14:53.848Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:14:53 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:15:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10012.556248000692, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:15:03.862Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:15:03 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 06:15:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10014.63058399895, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"68199a333ff792416d1f8d34\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T06:15:13.878Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 10, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 06:15:13 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 1, "serverConnectionId": 10, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# ...
# DEBUG - 2025-05-06 09:20:38 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:20:49 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10020.27276300214, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:20:49.005Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:20:49 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:20:59 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10019.765462002397, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:20:59.029Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:20:59 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:21:09 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10772.242977000133, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:21:09.032Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:21:09 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:21:19 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10014.790547000302, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:21:19.051Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:21:19 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:21:29 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10020.195897999656, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:21:29.075Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:21:29 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:21:39 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10739.08573099834, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:21:39.090Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:21:39 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:21:49 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10022.292664998531, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:21:49.115Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:21:49 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:21:59 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10021.407298001577, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:21:59.140Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:21:59 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:22:09 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10758.523467000487, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:22:09.143Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:22:09 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:22:19 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10007.855167001253, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:22:19.154Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:22:19 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:22:29 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10008.978353998828, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:22:29.166Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:22:29 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:22:39 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10007.094903001416, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:22:39.177Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:22:39 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:22:49 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10817.173118997744, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:22:49.180Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:22:49 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:22:59 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 9996.657479001442, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:22:59.180Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:22:59 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:23:09 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10009.014575000037, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:23:09.193Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:23:09 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:23:19 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10792.323585999839, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:23:19.194Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:23:19 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG - 2025-05-06 09:23:29 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "durationMS": 10054.68771500091, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6819d2fd10bf9dcad3ed5b1c\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2025-05-06T09:23:29.251Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 7, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG - 2025-05-06 09:23:29 - pymongo.topology - {"topologyId": {"$oid": "6819a711da53a29b9107c1de"}, "driverConnectionId": 56, "serverConnectionId": 7, "serverHost": "localhost", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}

# %%
tok_dataset.vocabulary
# Out:
# DEBUG - 2025-05-06 06:07:17 - pymongo.serverSelection - {"message": "Server selection started", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Standalone, rtt: 0.0010107979996973881>]>", "clientId": {"$oid": "6819a711da53a29b9107c1de"}}
# DEBUG - 2025-05-06 06:07:17 - pymongo.serverSelection - {"message": "Server selection succeeded", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Standalone, rtt: 0.0010107979996973881>]>", "clientId": {"$oid": "6819a711da53a29b9107c1de"}, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:17 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checkout started", "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:17 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection created", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1}
# DEBUG - 2025-05-06 06:07:17 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection ready", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1, "durationMS": 0.0008513679986208444}
# DEBUG - 2025-05-06 06:07:17 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checked out", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1, "durationMS": 0.003399353001441341}
# DEBUG - 2025-05-06 06:07:17 - pymongo.command - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Command started", "command": "{\"find\": \"vocabulary\", \"filter\": {\"_id\": \"65ca57d67f455f390d05bf33.improved\"}, \"limit\": 1, \"singleBatch\": true, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"HU7UhEmZRsCPN1KmWak7BA==\", \"subType\": \"04\"}}}, \"$db\": \"tokenSeqDB\"}", "commandName": "find", "databaseName": "tokenSeqDB", "requestId": 2044897763, "operationId": 2044897763, "driverConnectionId": 1, "serverConnectionId": 12, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:17 - pymongo.command - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Command succeeded", "durationMS": 7.38, "reply": "{\"cursor\": {\"firstBatch\": [{\"_id\": \"65ca57d67f455f390d05bf33.improved\", \"vocabulary\": [\"c27750\", \"c7041\", \"c3091\", \"c19843\", \"c23232\", \"c27000\", \"c26372\", \"c38151\", \"c889\", \"c9052\", \"c19086\", \"c24251\", \"c15645\", \"c29417\", \"c33091\", \"c38177\", \"c10393\", \"c574\", \"c12667\", \"c27631\", \"c31151\", \"c8021\", \"c788\", \"c17837\", \"c7407\", \"c26041\", \"c15377\", \"c16136\", \"c16354\", \"c11811\", \"c20833\", \"c1521\", \"c22551\", \"c20414\", \"c23650\", \"c3962\", \"c37828\", \"c25792\", \"c36849\", \"c31302\", \"c32992\", \"c22168\", \"c28627\", \"c2429\", \"c10824\", \"c3006\", \"c10663\", \"c15168\", \"c21917\", \"c17964\", \"c3035\", \"c20816\", \"c26665\", \"c14446\", \"c16451\", \"c35639\", \"c35211\", \"c25841\", \"c28779\", \"c6976\", \"c8227\", \"c30480\", \"c18714\", \"c33544\", \"c13813\", \"c3268\", \"c8614\", \"c15566\", \"c37641\", \"c13122\", \"c30282\", \"c15517\", \"c30426\", \"c37415\", \"c25150\", \"c35393\", \"c39169\", \"c13094\", \"c20755\", \"c34005\", \"c33484\", \"c23914\", \"c38427\", \"c23436\", \"c3234\", \"c36837\", \"c3120\", \"c37252\", \"c8206\", \"c3201\", \"c11418\", \"c10850\", \"c6205\", \"c1632\",...", "commandName": "find", "databaseName": "tokenSeqDB", "requestId": 2044897763, "operationId": 2044897763, "driverConnectionId": 1, "serverConnectionId": 12, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:17 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checked in", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1}
# ['c27750',
#  'c7041',
#  'c3091',
#  'c19843',
#  'c23232',
#  'c27000',
#  'c26372',
#  'c38151',
#  'c889',
#  'c9052',
#  'c19086',
#  'c24251',
#  'c15645',
#  'c29417',
#  'c33091',
#  'c38177',
#  'c10393',
#  'c574',
#  'c12667',
#  'c27631',
#  'c31151',
#  'c8021',
#  'c788',
#  'c17837',
#  'c7407',
#  'c26041',
#  'c15377',
#  'c16136',
#  'c16354',
#  'c11811',
#  'c20833',
#  'c1521',
#  'c22551',
#  'c20414',
#  'c23650',
#  'c3962',
#  'c37828',
#  'c25792',
#  'c36849',
#  'c31302',
#  'c32992',
#  'c22168',
#  'c28627',
#  'c2429',
#  'c10824',
#  'c3006',
#  'c10663',
#  'c15168',
#  'c21917',
#  'c17964',
#  'c3035',
#  'c20816',
#  'c26665',
#  'c14446',
#  'c16451',
#  'c35639',
#  'c35211',
#  'c25841',
#  'c28779',
#  'c6976',
#  'c8227',
#  'c30480',
#  'c18714',
#  'c33544',
#  'c13813',
#  'c3268',
#  'c8614',
#  'c15566',
#  'c37641',
#  'c13122',
#  'c30282',
#  'c15517',
#  'c30426',
#  'c37415',
#  'c25150',
#  'c35393',
#  'c39169',
#  'c13094',
#  'c20755',
#  'c34005',
#  'c33484',
#  'c23914',
#  'c38427',
#  'c23436',
#  'c3234',
#  'c36837',
#  'c3120',
#  'c37252',
#  'c8206',
#  'c3201',
#  'c11418',
#  'c10850',
#  'c6205',
#  'c1632',
#  'c5516',
#  'c18506',
#  'c14192',
#  'c18641',
#  'c4139',
#  'c11031',
#  'c28700',
#  'c649',
#  'c33803',
#  'c22532',
#  'c31406',
#  'c24056',
#  'c31960',
#  'c17390',
#  'c35447',
#  'c21916',
#  'c33812',
#  'c10019',
#  'c19106',
#  'c12953',
#  'c29672',
#  'c17157',
#  'c22816',
#  'c28290',
#  'c13520',
#  'c19705',
#  'c26787',
#  'c11261',
#  'c20005',
#  'c24755',
#  'c5562',
#  'c36402',
#  'c27163',
#  'c16602',
#  'c24146',
#  'c24732',
#  'c2319',
#  'c37083',
#  'c17744',
#  'c37131',
#  'c21265',
#  'c23280',
#  'c31235',
#  'c6947',
#  'c11157',
#  'c38677',
#  'c31751',
#  'c17911',
#  'c1953',
#  'c30157',
#  'c22385',
#  'c13732',
#  'c15333',
#  'c16185',
#  'c5529',
#  'c26246',
#  'c24264',
#  'c28463',
#  'c39881',
#  'c3649',
#  'c7872',
#  'c27371',
#  'c24206',
#  'c5098',
#  'c28160',
#  'c23376',
#  'c26928',
#  'c23969',
#  'c17059',
#  'c21977',
#  'c6002',
#  'c36714',
#  'c27403',
#  'c27011',
#  'c30175',
#  'c32643',
#  'c17352',
#  'c6080',
#  'c19836',
#  'c8171',
#  'c22834',
#  'c12719',
#  'c10776',
#  'c14661',
#  'c16196',
#  'c31435',
#  'c18451',
#  'c10048',
#  'c32581',
#  'c34688',
#  'c32630',
#  'c39315',
#  'c36258',
#  'c28329',
#  'c25952',
#  'c33655',
#  'c3408',
#  'c38235',
#  'c1187',
#  'c26558',
#  'c23045',
#  'c35125',
#  'c4377',
#  'c39466',
#  'c22948',
#  'c17936',
#  'c12640',
#  'c39514',
#  'c35238',
#  'c9755',
#  'c38395',
#  'c7521',
#  'c30162',
#  'c5693',
#  'c27267',
#  'c11168',
#  'c17505',
#  'c26885',
#  'c31972',
#  'c14314',
#  'c9167',
#  'c2324',
#  'c39571',
#  'c37880',
#  'c12399',
#  'c12301',
#  'c33657',
#  'c4848',
#  'c8251',
#  'c31300',
#  'c30611',
#  'c33987',
#  'c11057',
#  'c30981',
#  'c32590',
#  'c37972',
#  'c28084',
#  'c8129',
#  'c13400',
#  'c1545',
#  'c33825',
#  'c38430',
#  'c34076',
#  'c16323',
#  'c31743',
#  'c38314',
#  'c13103',
#  'c28528',
#  'c29207',
#  'c16630',
#  'c34903',
#  'c8765',
#  'c17036',
#  'c29467',
#  'c36065',
#  'c13540',
#  'c18009',
#  'c37897',
#  'c13886',
#  'c28427',
#  'c39129',
#  'c1383',
#  'c2013',
#  'c32705',
#  'c13456',
#  'c20283',
#  'c13493',
#  'c4760',
#  'c39034',
#  'c14600',
#  'c4190',
#  'c1839',
#  'c4703',
#  'c25453',
#  'c29891',
#  'c38922',
#  'c39344',
#  'c36805',
#  'c39773',
#  'c2741',
#  'c5106',
#  'c15251',
#  'c32045',
#  'c34656',
#  'c9305',
#  'c39895',
#  'c14258',
#  'c24423',
#  'c34551',
#  'c3943',
#  'c14618',
#  'c25386',
#  'c28548',
#  'c34357',
#  'c22939',
#  'c29539',
#  'c23097',
#  'c8528',
#  'c1578',
#  'c10266',
#  'c19859',
#  'c33927',
#  'c9200',
#  'c11776',
#  'c24605',
#  'c24625',
#  'c33071',
#  'c25217',
#  'c11505',
#  'c34378',
#  'c4401',
#  'c18598',
#  'c5900',
#  'c2297',
#  'c12091',
#  'c15880',
#  'c21591',
#  'c24787',
#  'c19830',
#  'c37273',
#  'c5797',
#  'c16366',
#  'c19653',
#  'c20252',
#  'c316',
#  'c19667',
#  'c39611',
#  'c9084',
#  'c11032',
#  'c21999',
#  'c30300',
#  'c38276',
#  'c6679',
#  'c16558',
#  'c14891',
#  'c32075',
#  'c4057',
#  'c9206',
#  'c9353',
#  'c11187',
#  'c5185',
#  'c33536',
#  'c27728',
#  'c15835',
#  'c20132',
#  'c2336',
#  'c31554',
#  'c14289',
#  'c8559',
#  'c11479',
#  'c30262',
#  'c32197',
#  'c7081',
#  'c30445',
#  'c14908',
#  'c39224',
#  'c30503',
#  'c18437',
#  'c3028',
#  'c15948',
#  'c3593',
#  'c17169',
#  'c15033',
#  'c34514',
#  'c37830',
#  'c4253',
#  'c9695',
#  'c1680',
#  'c36284',
#  'c20631',
#  'c36688',
#  'c22413',
#  'c3019',
#  'c14420',
#  'c12014',
#  'c2009',
#  'c32123',
#  'c29482',
#  'c15901',
#  'c19734',
#  'c31729',
#  'c20662',
#  'c24417',
#  'c32009',
#  'c8394',
#  'c13638',
#  'c9656',
#  'c21618',
#  'c33014',
#  'c36295',
#  'c24232',
#  'c5007',
#  'c21942',
#  'c8580',
#  'c28721',
#  'c10231',
#  'c19846',
#  'c4469',
#  'c4616',
#  'c5631',
#  'c19623',
#  'c10360',
#  'c35846',
#  'c1304',
#  'c9081',
#  'c34727',
#  'c10217',
#  'c16147',
#  'c27716',
#  'c15587',
#  'c33469',
#  'c24883',
#  'c37164',
#  'c15883',
#  'c35686',
#  'c539',
#  'c15717',
#  'c16943',
#  'c33920',
#  'c38094',
#  'c26349',
#  'c34930',
#  'c17721',
#  'c3901',
#  'c39623',
#  'c30179',
#  'c3359',
#  'c17187',
#  'c9297',
#  'c15082',
#  'c11934',
#  'c6331',
#  'c31922',
#  'c31619',
#  'c5957',
#  'c21093',
#  'c32619',
#  'c25450',
#  'c7223',
#  'c4939',
#  'c5129',
#  'c34251',
#  'c35353',
#  'c764',
#  'c33485',
#  'c9692',
#  'c37254',
#  'c12276',
#  'c12843',
#  'c11277',
#  'c14447',
#  'c28762',
#  'c13990',
#  'c18196',
#  'c3188',
#  'c22008',
#  'c55',
#  'c32733',
#  'c25782',
#  'c7883',
#  'c37851',
#  'c3881',
#  'c29657',
#  'c14113',
#  'c18199',
#  'c39048',
#  'c7250',
#  'c17802',
#  'c12416',
#  'c12648',
#  'c23456',
#  'c156',
#  'c10894',
#  'c20574',
#  'c27688',
#  'c20173',
#  'c17270',
#  'c27061',
#  'c29519',
#  'c25071',
#  'c1025',
#  'c13596',
#  'c2674',
#  'c28643',
#  'c6227',
#  'c25750',
#  'c6731',
#  'c7362',
#  'c422',
#  'c20918',
#  'c21384',
#  'c21760',
#  'c24432',
#  'c25244',
#  'c29600',
#  'c29841',
#  'c16505',
#  'c6675',
#  'c15161',
#  'c18254',
#  'c21681',
#  'c24541',
#  'c39419',
#  'c27839',
#  'c36236',
#  'c3585',
#  'c37437',
#  'c32404',
#  'c726',
#  'c23619',
#  'c27890',
#  'c33681',
#  'c22735',
#  'c34650',
#  'c29204',
#  'c31685',
#  'c2342',
#  'c959',
#  'c12607',
#  'c33944',
#  'c27459',
#  'c26653',
#  'c29811',
#  'c11492',
#  'c16590',
#  'c16915',
#  'c5784',
#  'c15038',
#  'c22452',
#  'c18912',
#  'c17091',
#  'c12680',
#  'c12135',
#  'c2968',
#  'c15608',
#  'c20060',
#  'c31107',
#  'c7302',
#  'c28560',
#  'c2587',
#  'c37915',
#  'c23503',
#  'c34367',
#  'c762',
#  'c29896',
#  'c27692',
#  'c11138',
#  'c12895',
#  'c1555',
#  'c21503',
#  'c32869',
#  'c8949',
#  'c20531',
#  'c37617',
#  'c3630',
#  'c14603',
#  'c30709',
#  'c1878',
#  'c2893',
#  'c883',
#  'c39746',
#  'c25999',
#  'c22929',
#  'c32717',
#  'c11325',
#  'c9386',
#  'c37715',
#  'c34809',
#  'c24640',
#  'c27980',
#  'c39575',
#  'c13517',
#  'c3935',
#  'c28795',
#  'c11749',
#  'c19333',
#  'c9595',
#  'c22562',
#  'c1825',
#  'c20126',
#  'c6751',
#  'c25812',
#  'c19279',
#  'c32391',
#  'c26805',
#  'c28199',
#  'c19777',
#  'c15116',
#  'c4733',
#  'c5646',
#  'c14927',
#  'c39609',
#  'c31969',
#  'c14951',
#  'c33501',
#  'c25030',
#  'c27435',
#  'c15010',
#  'c7328',
#  'c28879',
#  'c9704',
#  'c14582',
#  'c24276',
#  'c25942',
#  'c20272',
#  'c38126',
#  'c8284',
#  'c28702',
#  'c37103',
#  'c17409',
#  'c27774',
#  'c34519',
#  'c5878',
#  'c38631',
#  'c2553',
#  'c28247',
#  'c17910',
#  'c33742',
#  'c2201',
#  'c17291',
#  'c6239',
#  'c33180',
#  'c11675',
#  'c22091',
#  'c21613',
#  'c24011',
#  'c12638',
#  'c18425',
#  'c19578',
#  'c32016',
#  'c34657',
#  'c11080',
#  'c16262',
#  'c12373',
#  'c15051',
#  'c37380',
#  'c2281',
#  'c35624',
#  'c36172',
#  'c14836',
#  'c12109',
#  'c21949',
#  'c14097',
#  'c35200',
#  'c38105',
#  'c23496',
#  'c11863',
#  'c37798',
#  'c10505',
#  'c1338',
#  'c17513',
#  'c26241',
#  'c32742',
#  'c39024',
#  'c11160',
#  'c26835',
#  'c28706',
#  'c17543',
#  'c38701',
#  'c3864',
#  'c7460',
#  'c20806',
#  'c38665',
#  'c8389',
#  'c32244',
#  'c17742',
#  'c23922',
#  'c22845',
#  'c24193',
#  'c1605',
#  'c23550',
#  'c35648',
#  'c12001',
#  'c11676',
#  'c12776',
#  'c11333',
#  'c9325',
#  'c7585',
#  'c21005',
#  'c1208',
#  'c38199',
#  'c7964',
#  'c20568',
#  'c21621',
#  'c5174',
#  'c3336',
#  'c13995',
#  'c18032',
#  'c105',
#  'c29776',
#  'c12807',
#  'c39394',
#  'c16401',
#  'c4044',
#  'c30823',
#  'c39359',
#  'c6475',
#  'c8214',
#  'c21001',
#  'c15153',
#  'c13289',
#  'c16208',
#  'c10306',
#  'c4678',
#  'c28174',
#  'c31478',
#  'c12687',
#  'c560',
#  'c13279',
#  'c31848',
#  'c28994',
#  'c9337',
#  'c37524',
#  'c10142',
#  'c28376',
#  'c15243',
#  'c19377',
#  'c35003',
#  'c18888',
#  'c11612',
#  'c1874',
#  'c16199',
#  'c10768',
#  'c11279',
#  'c8986',
#  'c25604',
#  'c1263',
#  'c31269',
#  'c3153',
#  'c26657',
#  'c24913',
#  'c25778',
#  'c16619',
#  'c28215',
#  'c12864',
#  'c26361',
#  'c35257',
#  'c28940',
#  'c643',
#  'c38645',
#  'c35392',
#  'c31102',
#  'c32049',
#  'c6627',
#  'c19783',
#  'c13002',
#  'c18184',
#  'c28563',
#  'c2326',
#  'c19761',
#  'c11030',
#  'c19652',
#  'c20610',
#  'c27729',
#  'c23693',
#  'c2951',
#  'c2490',
#  'c17934',
#  'c5438',
#  'c1138',
#  'c3142',
#  'c34163',
#  'c31547',
#  'c13010',
#  'c3243',
#  'c2844',
#  'c32645',
#  'c31297',
#  'c26898',
#  'c23056',
#  'c39510',
#  'c34608',
#  'c31446',
#  'c30817',
#  'c10951',
#  'c4033',
#  'c2350',
#  'c3778',
#  'c30138',
#  'c14445',
#  'c4375',
#  'c6771',
#  'c7339',
#  'c17027',
#  'c6964',
#  'c7827',
#  'c33725',
#  'c26998',
#  'c20926',
#  'c39556',
#  'c12681',
#  'c37987',
#  'c36574',
#  'c3673',
#  'c18652',
#  'c11113',
#  'c10412',
#  'c35700',
#  'c36671',
#  'c25171',
#  'c35099',
#  'c29564',
#  'c26395',
#  'c4496',
#  'c23916',
#  'c8512',
#  'c6408',
#  'c22540',
#  'c12284',
#  'c9487',
#  'c17902',
#  'c23263',
#  'c2373',
#  'c8035',
#  'c16024',
#  'c3493',
#  'c13354',
#  'c11781',
#  'c22989',
#  'c17456',
#  'c11507',
#  'c20712',
#  'c23305',
#  'c3698',
#  'c36918',
#  'c12215',
#  'c31504',
#  'c37139',
#  'c39593',
#  'c3535',
#  'c21574',
#  'c26895',
#  'c28816',
#  'c33918',
#  'c25493',
#  'c36266',
#  'c39099',
#  'c22136',
#  'c5689',
#  'c38369',
#  'c29325',
#  'c10940',
#  'c9868',
#  'c29757',
#  'c8387',
#  'c14365',
#  'c23477',
#  'c12954',
#  'c24844',
#  'c32226',
#  'c20412',
#  'c30345',
#  'c4407',
#  'c10023',
#  'c24414',
#  'c28722',
#  'c16817',
#  'c29031',
#  'c12338',
#  'c7601',
#  'c38972',
#  'c30268',
#  'c13419',
#  'c6166',
#  'c15525',
#  'c39708',
#  'c18869',
#  'c14091',
#  'c23153',
#  'c39818',
#  'c9329',
#  'c13702',
#  'c8646',
#  'c15090',
#  'c39539',
#  'c28298',
#  'c15156',
#  'c9101',
#  'c18137',
#  'c23250',
#  'c2002',
#  'c2509',
#  'c28987',
#  'c17020',
#  'c17712',
#  'c33053',
#  'c16649',
#  'c12880',
#  'c25939',
#  'c30215',
#  'c5068',
#  'c5410',
#  'c6141',
#  'c8936',
#  'c29140',
#  'c19858',
#  'c33802',
#  'c32653',
#  'c32526',
#  'c33735',
#  'c39250',
#  'c11984',
#  'c17328',
#  'c2972',
#  'c38689',
#  'c13849',
#  'c28091',
#  'c8871',
#  'c32468',
#  'c32138',
#  'c17727',
#  'c24333',
#  'c2773',
#  'c13139',
#  'c14202',
#  'c7270',
#  'c12614',
#  'c3412',
#  'c34123',
#  'c27605',
#  'c30629',
#  'c20425',
#  'c5186',
#  'c462',
#  'c557',
#  'c33144',
#  'c25451',
#  'c25167',
#  'c7681',
#  'c36124',
#  'c10799',
#  'c39503',
#  'c23504',
#  'c18678',
#  'c18579',
#  'c29398',
#  'c32256',
#  'c33513',
#  'c14263',
#  'c3381',
#  'c11960',
#  'c39091',
#  'c14892',
#  'c528',
#  'c6033',
#  'c38424',
#  'c38049',
#  'c39900',
#  'c17932',
#  'c31730',
#  'c22324',
#  'c27374',
#  'c31787',
#  'c9986',
#  'c12126',
#  'c4594',
#  'c64',
#  'c20002',
#  'c15373',
#  'c6189',
#  'c15770',
#  'c2673',
#  'c21829',
#  'c26628',
#  'c7162',
#  'c17124',
#  'c9089',
#  'c5167',
#  'c29296',
#  'c28136',
#  'c2188',
#  'c36868',
#  'c5809',
#  'c4442',
#  'c12994',
#  'c18590',
#  'c10135',
#  'c26706',
#  'c10759',
#  'c39809',
#  'c26269',
#  'c34715',
#  'c13621',
#  'c18411',
#  'c1082',
#  'c28863',
#  'c32546',
#  'c28582',
#  'c14010',
#  'c38730',
#  'c35298',
#  'c32944',
#  'c4744',
#  'c22440',
#  'c33428',
#  'c22050',
#  'c16806',
#  'c22224',
#  'c10469',
#  'c18630',
#  'c27345',
#  'c20276',
#  'c4653',
#  'c9219',
#  'c33601',
#  'c31286',
#  ...]

# %%
# Load tokenizer mapping tokens to indices.
tokenizer = DictTokenizer(tok_dataset.vocabulary)
# Construct model config object.
# Out:
# DEBUG - 2025-05-06 06:07:23 - pymongo.serverSelection - {"message": "Server selection started", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Standalone, rtt: 0.00083982883959834>]>", "clientId": {"$oid": "6819a711da53a29b9107c1de"}}
# DEBUG - 2025-05-06 06:07:23 - pymongo.serverSelection - {"message": "Server selection succeeded", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Standalone, rtt: 0.00083982883959834>]>", "clientId": {"$oid": "6819a711da53a29b9107c1de"}, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:23 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checkout started", "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:23 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checked out", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1, "durationMS": 0.0005128039992996491}
# DEBUG - 2025-05-06 06:07:23 - pymongo.command - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Command started", "command": "{\"find\": \"vocabulary\", \"filter\": {\"_id\": \"65ca57d67f455f390d05bf33.improved\"}, \"limit\": 1, \"singleBatch\": true, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"HU7UhEmZRsCPN1KmWak7BA==\", \"subType\": \"04\"}}}, \"$db\": \"tokenSeqDB\"}", "commandName": "find", "databaseName": "tokenSeqDB", "requestId": 1365180540, "operationId": 1365180540, "driverConnectionId": 1, "serverConnectionId": 12, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:23 - pymongo.command - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Command succeeded", "durationMS": 4.327, "reply": "{\"cursor\": {\"firstBatch\": [{\"_id\": \"65ca57d67f455f390d05bf33.improved\", \"vocabulary\": [\"c27750\", \"c7041\", \"c3091\", \"c19843\", \"c23232\", \"c27000\", \"c26372\", \"c38151\", \"c889\", \"c9052\", \"c19086\", \"c24251\", \"c15645\", \"c29417\", \"c33091\", \"c38177\", \"c10393\", \"c574\", \"c12667\", \"c27631\", \"c31151\", \"c8021\", \"c788\", \"c17837\", \"c7407\", \"c26041\", \"c15377\", \"c16136\", \"c16354\", \"c11811\", \"c20833\", \"c1521\", \"c22551\", \"c20414\", \"c23650\", \"c3962\", \"c37828\", \"c25792\", \"c36849\", \"c31302\", \"c32992\", \"c22168\", \"c28627\", \"c2429\", \"c10824\", \"c3006\", \"c10663\", \"c15168\", \"c21917\", \"c17964\", \"c3035\", \"c20816\", \"c26665\", \"c14446\", \"c16451\", \"c35639\", \"c35211\", \"c25841\", \"c28779\", \"c6976\", \"c8227\", \"c30480\", \"c18714\", \"c33544\", \"c13813\", \"c3268\", \"c8614\", \"c15566\", \"c37641\", \"c13122\", \"c30282\", \"c15517\", \"c30426\", \"c37415\", \"c25150\", \"c35393\", \"c39169\", \"c13094\", \"c20755\", \"c34005\", \"c33484\", \"c23914\", \"c38427\", \"c23436\", \"c3234\", \"c36837\", \"c3120\", \"c37252\", \"c8206\", \"c3201\", \"c11418\", \"c10850\", \"c6205\", \"c1632\",...", "commandName": "find", "databaseName": "tokenSeqDB", "requestId": 1365180540, "operationId": 1365180540, "driverConnectionId": 1, "serverConnectionId": 12, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:07:23 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checked in", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1}
# INFO - 2025-05-06 06:07:23 - root - Vocabulary size: 40016

# %%
enc_dec_config = EncoderDecoderConfig.from_name(
    enc_name=ckpt.config_obj.encoder,
    dec_name=ckpt.config_obj.decoder,
    vocab_size=tokenizer.vocab_size,
)
# Construct model from config.
model = enc_dec_config.construct_model()
# Loading trained weights into model.
model.load_state_dict(ckpt.model_only_state_dict)
# Out:
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# DEBUG - 2025-05-06 06:07:27 - root - Creating block: n_heads=4, dim=384.
# <All keys matched successfully>

# %% [markdown]
# The following code segment loads the first test prompt and prints it.

# %%
print(model)
# Out:
# EncoderDecoder(
#   (encoder): Encoder(
#     (embedding): Embedding(40016, 384)
#     (rope): RoPE()
#     (layers): ModuleList(
#       (0-7): 8 x SelfAttentionBlock(
#         (attention): Attention(
#           (rope): RoPE()
#           (wq): Linear(in_features=384, out_features=384, bias=False)
#           (wk): Linear(in_features=384, out_features=384, bias=False)
#           (wv): Linear(in_features=384, out_features=384, bias=False)
#           (wo): Linear(in_features=384, out_features=384, bias=False)
#         )
#         (feed_forward): FeedForward(
#           (w1): Linear(in_features=384, out_features=1024, bias=False)
#           (w2): Linear(in_features=1024, out_features=384, bias=False)
#           (w3): Linear(in_features=384, out_features=1024, bias=False)
#         )
#         (attention_norm): RMSLayerNorm(normalized_shape=torch.Size([384])eps=1e-05elementwise_affine=True)
#         (ffn_norm): RMSLayerNorm(normalized_shape=torch.Size([384])eps=1e-05elementwise_affine=True)
#       )
#     )
#     (output): Sequential(
#       (0): RMSLayerNorm(normalized_shape=torch.Size([384])eps=1e-05elementwise_affine=True)
#       (1): Linear(in_features=384, out_features=384, bias=False)
#     )
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(40016, 384)
#     (rope): RoPE()
#     (layers): ModuleList(
#       (0-7): 8 x FeatureConditionedBlock(
#         (attention): Attention(
#           (rope): RoPE()
#           (wq): Linear(in_features=384, out_features=384, bias=False)
#           (wk): Linear(in_features=384, out_features=384, bias=False)
#           (wv): Linear(in_features=384, out_features=384, bias=False)
#           (wo): Linear(in_features=384, out_features=384, bias=False)
#         )
#         (attention_feat): Attention(
#           (wq): Linear(in_features=384, out_features=384, bias=False)
#           (wk): Linear(in_features=384, out_features=384, bias=False)
#           (wv): Linear(in_features=384, out_features=384, bias=False)
#           (wo): Linear(in_features=384, out_features=384, bias=False)
#         )
#         (feed_forward): FeedForward(
#           (w1): Linear(in_features=384, out_features=1024, bias=False)
#           (w2): Linear(in_features=1024, out_features=384, bias=False)
#           (w3): Linear(in_features=384, out_features=1024, bias=False)
#         )
#         (attention_norm): RMSLayerNorm(normalized_shape=torch.Size([384])eps=1e-05elementwise_affine=True)
#         (attention_feat_norm): RMSLayerNorm(normalized_shape=torch.Size([384])eps=1e-05elementwise_affine=True)
#         (ffn_norm): RMSLayerNorm(normalized_shape=torch.Size([384])eps=1e-05elementwise_affine=True)
#       )
#     )
#     (output): Sequential(
#       (0): RMSLayerNorm(normalized_shape=torch.Size([384])eps=1e-05elementwise_affine=True)
#       (1): Linear(in_features=384, out_features=40016, bias=False)
#     )
#   )
# )

# %%
test_trace_id_list = tok_dataset.test_ids
# Out:
# DEBUG - 2025-05-06 06:08:24 - root - Loading all ids from Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, sockettimeoutms=1800000, connecttimeoutms=1800000), 'tokenSeqDB'), '65ca57d67f455f390d05bf33.improved.meta.test') ...
# DEBUG - 2025-05-06 06:08:24 - pymongo.serverSelection - {"message": "Server selection started", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Standalone, rtt: 0.0005582851399910637>]>", "clientId": {"$oid": "6819a711da53a29b9107c1de"}}
# DEBUG - 2025-05-06 06:08:24 - pymongo.serverSelection - {"message": "Server selection succeeded", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Standalone, rtt: 0.0005582851399910637>]>", "clientId": {"$oid": "6819a711da53a29b9107c1de"}, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:08:24 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checkout started", "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:08:24 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checked out", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1, "durationMS": 0.0005426299994724104}
# DEBUG - 2025-05-06 06:08:24 - pymongo.command - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Command started", "command": "{\"find\": \"65ca57d67f455f390d05bf33.improved.meta.test\", \"projection\": {\"_id\": 1}, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"HU7UhEmZRsCPN1KmWak7BA==\", \"subType\": \"04\"}}}, \"$db\": \"tokenSeqDB\"}", "commandName": "find", "databaseName": "tokenSeqDB", "requestId": 278722862, "operationId": 278722862, "driverConnectionId": 1, "serverConnectionId": 12, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:08:24 - pymongo.command - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Command succeeded", "durationMS": 1.485, "reply": "{\"cursor\": {\"ns\": \"tokenSeqDB.65ca57d67f455f390d05bf33.improved.meta.test\"}, \"ok\": 1.0}", "commandName": "find", "databaseName": "tokenSeqDB", "requestId": 278722862, "operationId": 278722862, "driverConnectionId": 1, "serverConnectionId": 12, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:08:24 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checked in", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1}
# DEBUG - 2025-05-06 06:08:24 - root - Finished loading.

# %%
ckpt.config_obj
# Out:
# {'train_name': '65ca57d67f455f390d05bf33.improved',
#  'test_name': 'sokoban.7-by-7-walls-2-boxes-2.with-box-40k',
#  'batch_size': 1,
#  'plan_only': False,
#  'num_train_sequences': 100000,
#  'num_test_sequences': 1000,
#  'load_batch_size': 10000,
#  'num_workers': 2,
#  'min_reasoning_len': 0,
#  'max_reasoning_len': 10000}

# %%
tok_dataset.train_ids
# Out:
# DEBUG - 2025-05-06 06:13:49 - root - Loading all ids from Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, sockettimeoutms=1800000, connecttimeoutms=1800000), 'tokenSeqDB'), '65ca57d67f455f390d05bf33.improved.meta.train') ...
# DEBUG - 2025-05-06 06:13:49 - pymongo.serverSelection - {"message": "Server selection started", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Standalone, rtt: 0.00044676434307125326>]>", "clientId": {"$oid": "6819a711da53a29b9107c1de"}}
# DEBUG - 2025-05-06 06:13:49 - pymongo.serverSelection - {"message": "Server selection succeeded", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 6819a711da53a29b9107c1de, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Standalone, rtt: 0.00044676434307125326>]>", "clientId": {"$oid": "6819a711da53a29b9107c1de"}, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:13:49 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checkout started", "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:13:49 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checked out", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1, "durationMS": 0.0008883770005922997}
# DEBUG - 2025-05-06 06:13:49 - pymongo.command - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Command started", "command": "{\"find\": \"65ca57d67f455f390d05bf33.improved.meta.train\", \"projection\": {\"_id\": 1}, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"HU7UhEmZRsCPN1KmWak7BA==\", \"subType\": \"04\"}}}, \"$db\": \"tokenSeqDB\"}", "commandName": "find", "databaseName": "tokenSeqDB", "requestId": 135497281, "operationId": 135497281, "driverConnectionId": 1, "serverConnectionId": 12, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:13:49 - pymongo.command - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Command succeeded", "durationMS": 1.501, "reply": "{\"cursor\": {\"ns\": \"tokenSeqDB.65ca57d67f455f390d05bf33.improved.meta.train\"}, \"ok\": 1.0}", "commandName": "find", "databaseName": "tokenSeqDB", "requestId": 135497281, "operationId": 135497281, "driverConnectionId": 1, "serverConnectionId": 12, "serverHost": "localhost", "serverPort": 27017}
# DEBUG - 2025-05-06 06:13:49 - pymongo.connection - {"clientId": {"$oid": "6819a711da53a29b9107c1de"}, "message": "Connection checked in", "serverHost": "localhost", "serverPort": 27017, "driverConnectionId": 1}
# DEBUG - 2025-05-06 06:13:49 - root - Finished loading.
# []

# %%
test_trace_id_list
# Out:
# []

# %%
test_trace = next(iter(tok_dataset.test_it(test_trace_id_list[:1])))[0]
# Out:
# DEBUG - 2025-05-06 06:08:37 - root - Iterating over 0 ids.
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 test_trace = next(iter(tok_dataset.test_it(test_trace_id_list[:1])))[0]
#
# StopIteration:

# %%
prompt_str = " ".join(test_trace.prompt)
prompt_str = prompt_str.replace("start", "\n\tstart")
prompt_str = prompt_str.replace("wall", "\n\twall ")
prompt_str = prompt_str.replace("goal", "\n\tgoal ")
print("Prompt: " + prompt_str)

# %% [markdown]
# The following code segment maps the prompt to an integer tensor and then generates a response sequence.
# This response sequence (a integer tensor) is then decoded into a token sequence and printed.

# %%
prompt_tokens = tokenizer.encode(test_trace.prompt)
prompt_tokens_tensor = torch.Tensor(prompt_tokens).long()
response = model.rollout(
    prompt=prompt_tokens_tensor,
    bos_idx=tokenizer.bos,
    eos_idx=tokenizer.eos,
    max_rollout_len=2000,
    sample_fn=sample_probability,
)
response_token_list = tokenizer.decode(response[0].tolist())
print("Response:" + " ".join(response_token_list).replace("bos ", "\n\tbos").replace("eos", "\n\teos").replace("create", "\n\tcreate").replace("close", "\n\tclose ").replace("plan ", "\n\tplan   "))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 prompt_tokens = tokenizer.encode(test_trace.prompt)
#       2 prompt_tokens_tensor = torch.Tensor(prompt_tokens).long()
#       3 response = model.rollout(
#       4     prompt=prompt_tokens_tensor,
#       5     bos_idx=tokenizer.bos,
#    (...)      8     sample_fn=sample_probability,
#       9 )
#
# NameError: name 'tokenizer' is not defined
